# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300

# %%
sal=pd.concat([pd.read_csv(f"salaries/p_{yr}.csv") for yr in range(2018,2010,-1)])
sal=sal.groupby("name").first()
sal.head(50)
# Out:
#                                      title     salary  benefits
# name
# A. Tupling                       Professor  180567.92    519.72
# A.Russell Tupling                Professor  166933.16    578.96
# Abigail Scholer        Associate Professor  132597.73    373.00
# Achim Kempf                      Professor  187834.44    395.88
# Ada Barlatt            Assistant Professor  102159.48    359.08
# Ada Hurst                         Lecturer  128921.00    380.48
# Adam Kolkiewicz        Associate Professor  175958.20    519.36
# Adam Neale                        Lecturer  102058.60    169.28
# Adam Tsen              Assistant Professor  128595.20    147.44
# Adam Vitalis           Assistant Professor  178572.56    181.60
# Adel Sedra                       Professor  183584.56    175.98
# Adil Al-Mayah          Associate Professor  139878.18    319.12
# Adrian Blackwell       Associate Professor  140825.64    428.60
# Adrian Gerlich         Associate Professor  155205.36    433.36
# Adrian Lupascu         Associate Professor  146774.36    379.96
# Adrienne Gilbert                  Lecturer  117182.04    664.40
# Adrienne Lo            Associate Professor  123663.84    154.48
# Aimee Morrison         Associate Professor  120316.96    417.40
# Aiping Yu              Associate Professor  135405.98    185.08
# Ajit Singh             Associate Professor  152691.56    591.16
# Ajoy Opal                        Professor  187565.92    581.80
# Alain Gamache                     Lecturer  109462.60    164.04
# Alain-Desire Nimubona  Associate Professor  141361.48    427.52
# Alan Douglas           Associate Professor  259757.20    243.16
# Alan Huang             Associate Professor  218708.42    542.28
# Alan Macnaughton       Associate Professor  184475.52    392.96
# Alan Webb                        Professor  282151.52    596.68
# Alastair Craik         Associate Professor  176691.44    521.56
# Alejandro Lopez-Ortiz            Professor  184477.28    657.40
# Alexander Nelson       Assistant Professor  121879.88    359.60
# Alexander Penlidis               Professor  218158.84    617.44
# Alexander Schied                 Professor  186146.56    549.56
# Alexander Statiev      Associate Professor  119498.04    163.16
# Alexander Wong         Associate Professor  170217.76    472.48
# Alexandru Nica                   Professor  176320.48    520.44
# Alexis Dolphin         Assistant Professor  105472.96    133.28
# Alfred Menezes                   Professor  191707.24    262.36
# Alfred Yu                        Professor  152582.44    420.60
# Ali Elkamel                      Professor  176689.08    563.88
# Ali Ghodsi Boushehri             Professor  148968.20    439.56
# Ali Mashtizadeh        Assistant Professor  152140.24    167.16
# Alice Kuzniar                    Professor  209921.44    265.56
# Alicja Muszynski       Associate Professor  154634.84    427.52
# Allan Cameron                    Professor  107929.16    523.40
# Allison Kelly          Assistant Professor  121780.68    333.16
# Allyson Giannikouris              Lecturer  107565.72    317.28
# Altay Coskun           Associate Professor  146422.16    432.08
# Amelia Clarke          Associate Professor  156323.28    443.60
# Amer Obeidi                       Lecturer  104035.40      0.00
# Amir Khajepour                   Professor  232812.52    588.36

# %%
import ast
df=pd.read_csv("averages_enrol.csv",converters={"ccode":ast.literal_eval})#,dtype={"ccode":list})
df[["term"]]=pd.Categorical(df.term)
df[["section"]]=pd.Categorical(df.section)
df
# Out:
#       term                         ccode section        instructor       org  \
# 0     1131                   [ACTSC 231]       1       Anne Mackay  1.600000
# 1     1131                   [ACTSC 231]      51    Carole Bernard  1.727273
# 2     1131                   [ACTSC 232]       1      James Adcock  1.360825
# 3     1131                   [ACTSC 331]       1         Rocky Cui  1.851064
# 4     1131                   [ACTSC 371]       1    Brent Matheson  2.221053
# ...    ...                           ...     ...               ...       ...
# 3784  1185          [STAT 430, STAT 830]       1  Fernando Camacho  3.081081
# 3785  1185                    [STAT 431]       1       Leilei Zeng  2.135135
# 3786  1185  [CM 761, STAT 440, STAT 840]       1       Ryan Browne  2.200000
# 3787  1185                    [STAT 443]       1        Hamy Fahmy  3.088235
# 3788  1185                   [MTHEL 131]       1   Michelle Lennox  2.100000
#
#       expl_lvl   q_treat    visual      oral      help  ...    attend  \
# 0     2.873239  1.536232  1.591549  1.676056  1.526316  ...  1.225352
# 1     2.909091  2.090909  1.700000  2.000000  1.444444  ...  1.000000
# 2     2.804124  1.453608  1.567010  1.268041  2.000000  ...  1.154639
# 3     2.744681  2.043478  1.978723  2.108696  1.515152  ...  1.297872
# 4     2.821053  2.000000  2.452632  2.242105  2.565217  ...  1.329787
# ...        ...       ...       ...       ...       ...  ...       ...
# 3784  2.937500  2.441176  3.351351  3.055556  2.400000  ...  1.472222
# 3785  2.729730  2.000000  1.945946  2.162162  1.733333  ...  1.216216
# 3786  2.933333  2.066667  2.357143  2.266667  1.500000  ...  1.533333
# 3787  3.000000  3.090909  3.323529  2.941176  3.076923  ...  1.794118
# 3788  2.700000  2.250000  2.100000  2.000000  2.600000  ...  1.700000
#
#         assign     notes  textbook   new_mat  assign_amt   outside  num_resp  \
# 0     1.588235  1.358209  2.036364  2.782609    2.901639  2.279412        71
# 1     1.300000  1.625000  1.333333  2.545455    2.818182  2.000000        11
# 2     1.604167  1.516129  1.865169  2.659794    2.927835  2.000000        97
# 3     1.500000  1.586207  1.878049  2.659574    2.755556  2.021277        47
# 4     1.741935  1.909091  2.271429  2.851064    3.021277  1.903226        95
# ...        ...       ...       ...       ...         ...       ...       ...
# 3784  2.108108  2.000000  1.666667  2.363636    3.171429  2.270270        37
# 3785  1.638889  1.821429  1.950000  2.888889    2.756757  2.540541        37
# 3786  1.600000  1.636364  1.000000  2.733333    2.666667  3.066667        15
# 3787  1.941176  2.055556  2.000000  2.424242    2.558824  2.647059        34
# 3788  2.300000  1.750000  2.444444  2.700000    2.750000  1.700000        10
#
#       enrolled  resp_rate
# 0          184   0.385870
# 1           18   0.611111
# 2          143   0.678322
# 3           95   0.494737
# 4          236   0.402542
# ...        ...        ...
# 3784       105   0.352381
# 3785       117   0.316239
# 3786        40   0.375000
# 3787       128   0.265625
# 3788        50   0.200000
#
# [3789 rows x 22 columns]

# %%
df.ccode.explode().apply(lambda x:x.split(" ",1)[0]).unique()
# Out:
# array(['ACTSC', 'AMATH', 'CS', 'PMATH', 'PHYS', 'CO', 'QIC', 'COMM',
#        'ECE', 'CM', 'MATBUS', 'MATH', 'MTHEL', 'STAT', 'SYDE', 'EARTH',
#        'SE', 'BIOL', 'ACC', 'ENGL'], dtype=object)

# %%
df1=df[df.num_resp>10] # only surveys with >10 responses
df1=df1.groupby("instructor").filter(lambda x:len(x)>2) # only teachers with >=3 classes
# df1["enrolled"]=df1[["enrolled","num_responses"]].max(axis=1)
# df1["response_rate"]=df1.num_responses/df1.enrolled
df1=pd.merge(df1,sal,how='left', left_on=["instructor"],right_on=['name']).drop(['benefits','section'],axis=1)
df1["title"].fillna(value="Lecturer",inplace=True)
df1
# Out:
#       term                         ccode         instructor       org  \
# 0     1131                   [ACTSC 232]       James Adcock  1.360825
# 1     1131                   [ACTSC 371]     Brent Matheson  2.221053
# 2     1131                   [ACTSC 372]         Peter Wood  1.435644
# 3     1131        [ACTSC 433, ACTSC 833]            Jun Cai  1.723077
# 4     1131        [ACTSC 446, ACTSC 846]         Ruodo Wang  2.308411
# ...    ...                           ...                ...       ...
# 3115  1185                    [STAT 372]  Matthias Schonlau  2.064516
# 3116  1185          [STAT 430, STAT 830]   Fernando Camacho  3.081081
# 3117  1185                    [STAT 431]        Leilei Zeng  2.135135
# 3118  1185  [CM 761, STAT 440, STAT 840]        Ryan Browne  2.200000
# 3119  1185                    [STAT 443]         Hamy Fahmy  3.088235
#
#       expl_lvl   q_treat    visual      oral      help  interest  ...  \
# 0     2.804124  1.453608  1.567010  1.268041  2.000000  1.641304  ...
# 1     2.821053  2.000000  2.452632  2.242105  2.565217  2.070588  ...
# 2     2.623762  1.400000  1.574257  1.386139  1.712121  1.590000  ...
# 3     2.859375  2.262295  1.923077  2.476923  2.352941  1.833333  ...
# 4     2.557692  1.990566  2.644860  2.679245  2.000000  2.031250  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 3115  3.101695  1.629032  2.290323  2.131148  1.744681  2.157895  ...
# 3116  2.937500  2.441176  3.351351  3.055556  2.400000  2.428571  ...
# 3117  2.729730  2.000000  1.945946  2.162162  1.733333  1.861111  ...
# 3118  2.933333  2.066667  2.357143  2.266667  1.500000  1.733333  ...
# 3119  3.000000  3.090909  3.323529  2.941176  3.076923  2.312500  ...
#
#          notes  textbook   new_mat  assign_amt   outside  num_resp  enrolled  \
# 0     1.516129  1.865169  2.659794    2.927835  2.000000        97       143
# 1     1.909091  2.271429  2.851064    3.021277  1.903226        95       236
# 2     1.785714  2.103896  2.762376    2.891089  1.930000       101       174
# 3     1.578947  2.166667  2.907692    2.707692  1.968750        65       107
# 4     1.819444  2.370968  2.538462    2.844660  2.038095       107       178
# ...        ...       ...       ...         ...       ...       ...       ...
# 3115  1.862745  1.962963  2.844828    3.100000  1.919355        62       160
# 3116  2.000000  1.666667  2.363636    3.171429  2.270270        37       105
# 3117  1.821429  1.950000  2.888889    2.756757  2.540541        37       117
# 3118  1.636364  1.000000  2.733333    2.666667  3.066667        15        40
# 3119  2.055556  2.000000  2.424242    2.558824  2.647059        34       128
#
#       resp_rate                title     salary
# 0      0.678322             Lecturer  136295.28
# 1      0.402542             Lecturer  128478.60
# 2      0.580460             Lecturer  162561.88
# 3      0.607477            Professor  161277.18
# 4      0.601124  Associate Professor  141182.60
# ...         ...                  ...        ...
# 3115   0.387500            Professor  175737.96
# 3116   0.352381             Lecturer        NaN
# 3117   0.316239  Associate Professor  154329.68
# 3118   0.375000  Assistant Professor  126343.24
# 3119   0.265625             Lecturer  113016.60
#
# [3120 rows x 23 columns]

# %%
df1.resp_rate.hist() # verify

# %%
df1.describe()
# Out:
#                org     expl_lvl      q_treat       visual         oral  \
# count  3120.000000  3120.000000  3120.000000  3120.000000  3120.000000
# mean      1.818678     2.811854     1.710346     1.925701     1.838593
# std       0.517105     0.201306     0.422051     0.498676     0.556056
# min       1.000000     1.615385     1.000000     1.055556     1.000000
# 25%       1.429928     2.705882     1.411765     1.551474     1.422729
# 50%       1.725541     2.823529     1.615385     1.837669     1.714286
# 75%       2.075835     2.933333     1.920088     2.200000     2.100000
# max       4.368421     3.866667     4.000000     3.916667     4.300000
#
#               help     interest      overall       attend       assign  \
# count  3120.000000  3120.000000  3120.000000  3120.000000  3120.000000
# mean      1.854170     1.801829     1.784624     1.421841     1.630494
# std       0.430123     0.296774     0.522716     0.315548     0.234056
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.550765     1.597015     1.387097     1.205128     1.470588
# 50%       1.809524     1.786950     1.675676     1.347382     1.604167
# 75%       2.111111     2.000000     2.031634     1.555556     1.769231
# max       4.333333     2.934783     4.333333     3.416667     2.642857
#
#              notes     textbook      new_mat   assign_amt      outside  \
# count  3120.000000  3120.000000  3120.000000  3120.000000  3120.000000
# mean      1.712246     1.892259     2.720941     2.746512     2.501956
# std       0.286208     0.352299     0.230634     0.280935     0.528582
# min       1.000000     1.000000     1.615385     1.402778     1.000000
# 25%       1.521513     1.666667     2.583022     2.586769     2.142857
# 50%       1.689655     1.890390     2.740741     2.788170     2.414864
# 75%       1.879091     2.115385     2.875000     2.937500     2.764706
# max       3.000000     3.000000     3.869565     3.923077     5.000000
#
#           num_resp     enrolled    resp_rate         salary
# count  3120.000000  3120.000000  3120.000000    2197.000000
# mean     44.758974    85.682051     0.554521  152660.204729
# std      27.004024    51.067635     0.165858   32401.015244
# min      11.000000    11.000000     0.096000  101601.080000
# 25%      26.000000    52.000000     0.428571  127862.980000
# 50%      39.000000    78.000000     0.542857  141315.160000
# 75%      57.000000   108.000000     0.666667  176320.480000
# max     242.000000   408.000000     1.000000  242904.120000

# %%
# most prolific profs
df1.groupby("instructor").size().sort_values(ascending=False).head(20)
# Out:
# instructor
# Victoria Sakhnini       38
# Mark Petrick            38
# Mukto Akash             33
# Nomair Naeem            33
# Brad Lushman            33
# Hamy Fahmy              33
# Collin Roberts          29
# Joe West                29
# Dave Tompkins           28
# Michael Liu             28
# Rosina Kharal Kharal    28
# James Adcock            27
# Lori Case               26
# Riley Metzger           26
# Dina Dawoud             26
# Keith Freeland          25
# Dan Wolczuk             25
# Dan Holtby              25
# Brent Matheson          24
# Kevin Lanctot           24
# dtype: int64

# %%
# Get a prof's courses 
df1.groupby("instructor").get_group("David Jao").explode("ccode").groupby("ccode")[["overall"]].mean()#.dropna()
# Out:
#            overall
# ccode
# CO 250    1.830986
# CO 331    1.695652
# CO 456    1.815789
# CO 485    1.295800
# CO 487    1.482573
# CO 685    1.295800
# CO 687    1.482573
# MATH 145  1.511055
# MATH 239  1.591667

# %%
def top(df1,col,n=10,asc=True):
    return df1.groupby("instructor")[[col]].mean().sort_values(ascending=asc,by=col).head(n)

# %%
top(df1,"organization",asc=False)
# Out:
#                    organization
# instructor
# David Toman            3.568939
# Iakov Nekrich          3.402525
# Daniela Maftuleac      3.370017
# Jonathan Buss          3.369061
# Steven Gindi           3.262924
# Edward Chan            3.178010
# Ian Davis              3.077991
# Ahmad Alrefai          3.056345
# Grant Weddell          2.994952
# Henry Wolkowicz        2.957951

# %%
# high overall rating profs
top(df1,"overall",asc=True)
# Out:
#                   overall
# instructor
# Mike Eden        1.119274
# Ryan Trelford    1.142239
# Brian Forrest    1.162014
# Johnny Li        1.188889
# Edward Dupont    1.191477
# Yu-Ru Liu        1.196314
# Ian Goldberg     1.197750
# Pengfei Li       1.204525
# Serge D'Alessio  1.207769
# Jordan Hamilton  1.211254

# %%
top(df1,"attendance",asc=True)
# Out:
#                     attendance
# instructor
# Paulo Alencar         1.059351
# Mark Arnason          1.071543
# Doug Andrews          1.074359
# Gladimir Baranoski    1.100677
# Jack Robinson         1.112824
# Brian Forrest         1.117745
# Jason Bell            1.119253
# J Ian Munro           1.126888
# Mary Hardy            1.142786
# Mike Eden             1.146512

# %%
### Predict course overall rating
from sklearn.linear_model import LinearRegression, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm

# feats=["help","interesting","visual","oral","q_treatment","expl_lvl","assign_helpful"]
feats=list(df1.select_dtypes('number').columns)
[feats.remove(xx) for xx in ["salary","num_resp","enrolled","overall"]]
nonlinear_feats=["expl_lvl","new_mat","assign_amt"]
X=df1[feats].copy()
X[nonlinear_feats]=abs(X[nonlinear_feats]-3)
X=X.drop(["org","oral","q_treat","visual","interest","help"],axis=1)
x1,x2,y1,y2=train_test_split(X,df1.overall,random_state=42)
# ss=StandardScaler()
# x1=pd.DataFrame(ss.fit_transform(x1),columns=x1.columns)
# x2=ss.transform(x2)


# x1 = np.array(x1)
x1i = sm.add_constant(x1, prepend=False)
# lr=LinearRegression()
# lr=LassoCV(cv=10)
# lr=RidgeCV(alphas=10.**np.arange(-3,3))
lr=sm.OLS(y1,x1i)
res1=lr.fit()
# lr.fit(x1,y1)
# print(f"train error: {np.mean(np.square(lr.predict(x1)-y1))}")
# print(f"test error:  {np.mean(np.square(lr.predict(x2)-y2))}")

# %%
res1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                overall   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     247.0
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):               0.00
# Time:                        16:16:26   Log-Likelihood:                -1044.8
# No. Observations:                2340   AIC:                             2110.
# Df Residuals:                    2330   BIC:                             2167.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# expl_lvl       0.3619      0.056      6.432      0.000       0.252       0.472
# attend         0.6016      0.028     21.132      0.000       0.546       0.657
# assign         0.6292      0.044     14.397      0.000       0.544       0.715
# notes          0.4084      0.033     12.506      0.000       0.344       0.472
# textbook       0.0175      0.024      0.716      0.474      -0.030       0.065
# new_mat        0.0554      0.050      1.116      0.265      -0.042       0.153
# assign_amt    -0.0430      0.050     -0.856      0.392      -0.142       0.056
# outside        0.0033      0.023      0.141      0.888      -0.042       0.049
# resp_rate     -0.2786      0.052     -5.328      0.000      -0.381      -0.176
# const         -0.7649      0.107     -7.147      0.000      -0.975      -0.555
# ==============================================================================
# Omnibus:                      227.141   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.595
# Skew:                           0.741   Prob(JB):                     9.89e-73
# Kurtosis:                       4.097   Cond. No.                         64.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.scatterplot(y1,y1-res1.predict())

# %%
print(res1.as_latex())
# Out:
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}    &     overall      & \textbf{  R-squared:         } &     0.968   \\
# \textbf{Model:}            &       OLS        & \textbf{  Adj. R-squared:    } &     0.968   \\
# \textbf{Method:}           &  Least Squares   & \textbf{  F-statistic:       } &     4735.   \\
# \textbf{Date:}             & Tue, 03 Dec 2019 & \textbf{  Prob (F-statistic):} &     0.00    \\
# \textbf{Time:}             &     12:33:45     & \textbf{  Log-Likelihood:    } &    2210.0   \\
# \textbf{No. Observations:} &        2340      & \textbf{  AIC:               } &    -4388.   \\
# \textbf{Df Residuals:}     &        2324      & \textbf{  BIC:               } &    -4296.   \\
# \textbf{Df Model:}         &          15      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                      & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{org}         &       0.3811  &        0.012     &    30.866  &         0.000        &        0.357    &        0.405     \\
# \textbf{expl\_lvl}   &      -0.0135  &        0.013     &    -1.060  &         0.289        &       -0.038    &        0.011     \\
# \textbf{q\_treat}    &       0.2457  &        0.011     &    22.984  &         0.000        &        0.225    &        0.267     \\
# \textbf{visual}      &       0.0867  &        0.010     &     8.411  &         0.000        &        0.067    &        0.107     \\
# \textbf{oral}        &       0.2879  &        0.010     &    28.497  &         0.000        &        0.268    &        0.308     \\
# \textbf{help}        &       0.0490  &        0.007     &     7.319  &         0.000        &        0.036    &        0.062     \\
# \textbf{interest}    &       0.0859  &        0.011     &     7.494  &         0.000        &        0.063    &        0.108     \\
# \textbf{attend}      &       0.0197  &        0.008     &     2.486  &         0.013        &        0.004    &        0.035     \\
# \textbf{assign}      &       0.0252  &        0.012     &     2.104  &         0.035        &        0.002    &        0.049     \\
# \textbf{notes}       &      -0.0223  &        0.009     &    -2.562  &         0.010        &       -0.039    &       -0.005     \\
# \textbf{textbook}    &      -0.0139  &        0.006     &    -2.241  &         0.025        &       -0.026    &       -0.002     \\
# \textbf{new\_mat}    &      -0.0174  &        0.012     &    -1.453  &         0.146        &       -0.041    &        0.006     \\
# \textbf{assign\_amt} &      -0.0108  &        0.012     &    -0.930  &         0.353        &       -0.034    &        0.012     \\
# \textbf{outside}     &       0.0094  &        0.006     &     1.459  &         0.145        &       -0.003    &        0.022     \\
# \textbf{resp\_rate}  &       0.0203  &        0.013     &     1.518  &         0.129        &       -0.006    &        0.047     \\
# \textbf{const}       &      -0.1946  &        0.060     &    -3.248  &         0.001        &       -0.312    &       -0.077     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 31.144 & \textbf{  Durbin-Watson:     } &    2.067  \\
# \textbf{Prob(Omnibus):} &  0.000 & \textbf{  Jarque-Bera (JB):  } &   54.395  \\
# \textbf{Skew:}          & -0.034 & \textbf{  Prob(JB):          } & 1.54e-12  \\
# \textbf{Kurtosis:}      &  3.744 & \textbf{  Cond. No.          } &     246.  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Warnings: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.metrics import r2_score
r2_score(lr.predict(x2),y2)
# Out:
# 0.9622526472211503

# %%
for feat,coef in sorted(zip(feats,lr.coef_),key=lambda x:abs(x[1]),reverse=True):
    print(f"{feat:<16} {coef:7.4f}") # lasso
# Out:
# organization      0.2005
# oral              0.1612
# q_treatment       0.1047
# visual            0.0432
# interesting       0.0245
# help              0.0205
# attendance        0.0057
# printed_notes    -0.0053
# assign_helpful    0.0053
# textbook         -0.0043
# new_material     -0.0041
# hours_outside     0.0041
# assign_amount    -0.0030
# response_rate     0.0024
# expl_lvl         -0.0021

# %%
lr.alpha_
# Out:
# 0.0005060099497114898

# %% [markdown]
# # Interpretation of Linear Regression coefficients
#
# Overall effectiveness rating correlates positively with:
# * Be organized!
# * Have good oral presentations
# * Answer students' questions well
#
# and to a lesser extent:
# * Have good visual presentations
# * Teach interesting courses
# * Be available for help
#
# Interesting notes:
# * Results are similar regardless of regularization method (or even no regularization). Thus we can be confident about robustness.
# * Organization is most important
# * Oral far more important than visual
# * Everything after first 6 features is pretty much unimportant (in the linear model)

# %%
# TENURE PREDICTOR!!!
dfp=df1
# dfp=df1[~df1.title.isna()]
dfp=dfp.groupby("instructor").mean()
dfp["num_taught"]=df1.groupby("instructor").size()
dfp["title"]=df1.groupby("instructor").first()[["title"]]
# dfp=dfp.reset_index()
feats=list(df1.select_dtypes('number').columns)
[feats.remove(xx) for xx in ["salary","num_responses","enrolled"]]
has_tenure=dfp.title.isin(["Professor","Associate Professor"])

xc1,xc2,yc1,yc2=train_test_split(dfp[feats],has_tenure,test_size=.2,random_state=42)
ss=StandardScaler()
xc1=ss.fit_transform(xc1)
xc2=ss.transform(xc2)

from sklearn.linear_model import LogisticRegression,LogisticRegressionCV
# lr2=LinearRegression()
# lr2=LassoCV(cv=5)
lr2=LogisticRegressionCV(penalty="l1",cv=5,solver='liblinear',max_iter=999,random_state=42)#penalty="l2",C=100,solver='lbfgs',max_iter=999)
lr2.fit(xc1,yc1)
print(f"train error: {np.mean(lr2.predict(xc1)!=yc1)}")
print(f"test error:  {np.mean(lr2.predict(xc2)!=yc2)}")
print(f"baseline:    {np.mean(has_tenure)}")
# Out:
# train error: 0.23487544483985764
# test error:  0.28169014084507044
# baseline:    0.42329545454545453

# %%
dfp.describe()
# Out:
#        organization    expl_lvl  q_treatment      visual        oral  \
# count    352.000000  352.000000   352.000000  352.000000  352.000000
# mean       1.878017    2.814417     1.741546    1.982659    1.912351
# std        0.458013    0.149639     0.377168    0.433375    0.527118
# min        1.159747    2.232028     1.071700    1.212847    1.117061
# 25%        1.542152    2.731409     1.467229    1.645455    1.533384
# 50%        1.812380    2.817823     1.655740    1.945837    1.786304
# 75%        2.110139    2.904577     1.965223    2.236544    2.184750
# max        3.568939    3.364158     3.338336    3.383198    3.802020
#
#              help  interesting     overall  attendance  assign_helpful  \
# count  352.000000   352.000000  352.000000  352.000000      352.000000
# mean     1.868371     1.813134    1.846388    1.443930        1.639686
# std      0.337078     0.241311    0.479670    0.239798        0.168894
# min      1.219240     1.203056    1.119274    1.059351        1.218639
# 25%      1.643571     1.631374    1.483373    1.285041        1.527895
# 50%      1.803285     1.815575    1.743527    1.389015        1.624975
# 75%      2.058872     1.970324    2.091365    1.533038        1.739176
# max      3.584168     2.503185    3.560606    2.813270        2.191727
#
#        printed_notes    textbook  new_material  assign_amount  hours_outside  \
# count     352.000000  352.000000    352.000000     352.000000     352.000000
# mean        1.720456    1.876030      2.724880       2.751774       2.499491
# std         0.191335    0.216929      0.160029       0.200509       0.404285
# min         1.229057    1.333333      2.196497       2.117114       1.613509
# 25%         1.582844    1.726592      2.636259       2.639084       2.229968
# 50%         1.724427    1.868713      2.727159       2.777266       2.452397
# 75%         1.853577    2.010879      2.821882       2.896335       2.702893
# max         2.323152    2.541667      3.167059       3.312912       4.204576
#
#        num_responses    enrolled  response_rate         salary  num_taught
# count     352.000000  352.000000     352.000000     224.000000  352.000000
# mean       41.924532   80.680223       0.555500  160133.308661    8.863636
# std        16.490914   30.604445       0.109371   33645.394311    6.669541
# min        14.000000   18.000000       0.298877  101601.080000    3.000000
# 25%        30.172727   61.875000       0.477224  132064.010000    4.000000
# 50%        38.962500   75.306897       0.551656  158109.080000    7.000000
# 75%        49.774845   98.208333       0.631409  182901.430000   11.000000
# max       114.692308  201.800000       0.947650  242904.120000   38.000000

# %%
for feat,coef in sorted(zip(feats,lr2.coef_[0]),key=lambda x:-abs(x[1])):
    print(f"{feat:<16} {coef:7.4f}")
# Out:
# expl_lvl         -0.7929
# new_material      0.6968
# response_rate     0.6226
# help              0.4989
# interesting      -0.3799
# printed_notes    -0.3158
# organization      0.3100
# assign_amount     0.2506
# hours_outside     0.2058
# assign_helpful   -0.1469
# oral              0.0014
# textbook         -0.0002
# q_treatment       0.0000
# visual            0.0000
# overall           0.0000
# attendance        0.0000

# %%
lr2.C_
# Out:
# array([0.35938137])

# %% [markdown]
# # Interpretation of Logistic Regression coefficients
#
# Tenured staff tend to:
# * Explain concepts at higher level
# * Introduce less new material
# * Have higher response rate on course evaluations
# * Be less available for help outside of class
# * Teach more interesting courses

# %%
# #############################################################################
# Display results

plt.figure(figsize=(10,10))
ax = plt.gca()

ax.plot(lr2.Cs_, np.mean(lr2.coefs_paths_[True],axis=0))
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim())
plt.xlabel('C')
plt.ylabel('weights')
plt.title('LASSO coefficients as a function of the regularization')
plt.axis('tight')
plt.legend(feats)
plt.show()

# %%
dfp.title.hist()

# %%
from sklearn.ensemble import RandomForestClassifier



xd1,xd2,yd1,yd2=train_test_split(dfp[feats],dfp.title,test_size=.2,random_state=42)
ss=StandardScaler()
xd1=ss.fit_transform(xd1)
xd2=ss.transform(xd2)


rf=RandomForestClassifier(n_estimators=1000,min_samples_leaf=5,max_depth=4,random_state=2)
rf.fit(xd1,yd1)
print(f"train error: {np.mean(rf.predict(xd1)!=yd1)}")
print(f"test error:  {np.mean(rf.predict(xd2)!=yd2)}")
print(f"baseline:    {np.mean(dfp.title=='Lecturer')}")
# Out:
# train error: 0.3096085409252669
# test error:  0.43661971830985913
# baseline:    0.5028409090909091

# %%
for feat,coef in sorted(zip(feats,rf.feature_importances_),key=lambda x:-abs(x[1])):
    print(f"{feat:<16} {coef:7.4f}")
# Out:
# interesting       0.1484
# response_rate     0.1261
# expl_lvl          0.1231
# assign_amount     0.0695
# assign_helpful    0.0679
# new_material      0.0660
# attendance        0.0573
# printed_notes     0.0465
# textbook          0.0431
# hours_outside     0.0427
# help              0.0395
# oral              0.0380
# organization      0.0372
# visual            0.0362
# q_treatment       0.0322
# overall           0.0264

# %%
from sklearn.svm import SVC

sv=SVC(random_state=12)
sv.fit(xd1,yd1)
print(f"train error: {np.mean(sv.predict(xd1)!=yd1)}")
print(f"test error:  {np.mean(sv.predict(xd2)!=yd2)}")
print(f"baseline:    {np.mean(dfp.title=='Lecturer')}")
# Out:
# train error: 0.28825622775800713
# test error:  0.4225352112676056
# baseline:    0.5028409090909091

# %%
lr3=LogisticRegression(multi_class="multinomial",solver="lbfgs")
lr3.fit(xd1,yd1)
print(f"train error: {np.mean(lr3.predict(xd1)!=yd1)}")
print(f"test error:  {np.mean(lr3.predict(xd2)!=yd2)}")
print(f"baseline:    {np.mean(dfp.title=='Lecturer')}")
for feat,coef in sorted(zip(feats,lr3.coef_[0]),key=lambda x:-abs(x[1])):
    print(f"{feat:<16} {coef:7.4f}")
# Out:
# train error: 0.33451957295373663
# test error:  0.39436619718309857
# baseline:    0.5028409090909091
# expl_lvl         -0.5162
# attendance        0.4720
# assign_amount     0.4582
# interesting      -0.3228
# overall          -0.2593
# hours_outside     0.2430
# printed_notes     0.1698
# assign_helpful    0.1560
# organization     -0.1315
# textbook         -0.1204
# response_rate    -0.1115
# help             -0.0730
# oral             -0.0645
# new_material      0.0565
# q_treatment       0.0433
# visual            0.0129

# %%
lr3
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
